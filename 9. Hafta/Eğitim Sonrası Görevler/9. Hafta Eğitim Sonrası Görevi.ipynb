# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
import random

class Kumanda:
    def __init__(self):
        self.tv_durum = "Kapali"
        self.ses = 0
        self.kanal_listesi = ["bilos"]
        self.aktif_kanal = "bilos"

    def tv_ac(self):
        self.tv_durum = "Acik"
        print("Televizyon açıldı")

    def tv_kapat(self):
        self.tv_durum = "Kapali"
        print("Televizyon kapandı")

    def ses_ayarla(self):
        yeni_ses = int(input("Yeni ses seviyesi (0-31): "))
        if 0 <= yeni_ses <= 31:
            self.ses = yeni_ses
            print(f"Ses seviyesi {self.ses}")
        else:
            print("Geçersiz ses seviyesi")

    def kanal_ekle(self, kanal_ismi):
        self.kanal_listesi.append(kanal_ismi)
        print(f"{kanal_ismi} kanalı eklendi")

    def kanal_sayisini_ogrenme(self):
        print(f"Toplam kanal sayısı: {len(self.kanal_listesi)}")

    def rastgele_kanal(self):
        self.aktif_kanal = random.choice(self.kanal_listesi)
        print(f"Rastgele kanal: {self.aktif_kanal}")

    def tv_bilgileri(self):
        print(f"Televizyon durumu: {self.tv_durum}")
        print(f"Ses seviyesi: {self.ses}")
        print(f"Aktif kanal: {self.aktif_kanal}")
        print(f"Kanal listesi: {self.kanal_listesi}")

def main():
    kumanda = Kumanda()
    while True:
        print("""
            1. TV Aç
            2. TV Kapat
            3. Ses Ayarları
            4. Kanal Ekle
            5. Kanal Sayısını Öğrenme
            6. Rastgele Kanala Geçme
            7. Televizyon Bilgileri
            Çıkış için 'q' tuşlayın.
            """)
        secim = input("Komutlardan birini seçiniz: ")

        if secim == '1':
            kumanda.tv_ac()
        elif secim == '2':
            kumanda.tv_kapat()
        elif secim == '3':
            kumanda.ses_ayarla()
        elif secim == '4':
            kanal_ismi = input("Eklenecek kanalın ismi: ")
            kumanda.kanal_ekle(kanal_ismi)
        elif secim == '5':
            kumanda.kanal_sayisini_ogrenme()
        elif secim == '6':
            kumanda.rastgele_kanal()
        elif secim == '7':
            kumanda.tv_bilgileri()
        elif secim == 'q' or secim == 'Q':
            print("Çıkış yapılıyor...")
            break
        else:
            print("Geçersiz seçim! Lütfen tekrar deneyin.")

if __name__ == "__main__":
    main()
# Out:
#             1. TV Aç
#             2. TV Kapat
#             3. Ses Ayarları
#             4. Kanal Ekle
#             5. Kanal Sayısını Öğrenme
#             6. Rastgele Kanala Geçme
#             7. Televizyon Bilgileri
#             Çıkış için 'q' tuşlayın.
#
# Toplam kanal sayısı: 1
#
#             1. TV Aç
#             2. TV Kapat
#             3. Ses Ayarları
#             4. Kanal Ekle
#             5. Kanal Sayısını Öğrenme
#             6. Rastgele Kanala Geçme
#             7. Televizyon Bilgileri
#             Çıkış için 'q' tuşlayın.
#
# Rastgele kanal: bilos
#
#             1. TV Aç
#             2. TV Kapat
#             3. Ses Ayarları
#             4. Kanal Ekle
#             5. Kanal Sayısını Öğrenme
#             6. Rastgele Kanala Geçme
#             7. Televizyon Bilgileri
#             Çıkış için 'q' tuşlayın.
#
# Televizyon durumu: Kapali
# Ses seviyesi: 0
# Aktif kanal: bilos
# Kanal listesi: ['bilos']
#
#             1. TV Aç
#             2. TV Kapat
#             3. Ses Ayarları
#             4. Kanal Ekle
#             5. Kanal Sayısını Öğrenme
#             6. Rastgele Kanala Geçme
#             7. Televizyon Bilgileri
#             Çıkış için 'q' tuşlayın.
#
# Televizyon kapandı
#
#             1. TV Aç
#             2. TV Kapat
#             3. Ses Ayarları
#             4. Kanal Ekle
#             5. Kanal Sayısını Öğrenme
#             6. Rastgele Kanala Geçme
#             7. Televizyon Bilgileri
#             Çıkış için 'q' tuşlayın.
#
# Televizyon kapandı
#
#             1. TV Aç
#             2. TV Kapat
#             3. Ses Ayarları
#             4. Kanal Ekle
#             5. Kanal Sayısını Öğrenme
#             6. Rastgele Kanala Geçme
#             7. Televizyon Bilgileri
#             Çıkış için 'q' tuşlayın.
#
# Televizyon durumu: Kapali
# Ses seviyesi: 0
# Aktif kanal: bilos
# Kanal listesi: ['bilos']
#
#             1. TV Aç
#             2. TV Kapat
#             3. Ses Ayarları
#             4. Kanal Ekle
#             5. Kanal Sayısını Öğrenme
#             6. Rastgele Kanala Geçme
#             7. Televizyon Bilgileri
#             Çıkış için 'q' tuşlayın.
#
# Çıkış yapılıyor...
