# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız

with open("urunler.txt", "r+", encoding= "utf - 8") as file:
    urunAdi = input("Urun ismi nedir: ")
    urunFiyati = int(input("Urun fiyati nedir: "))

    veri = (f"{urunAdi}, {urunFiyati} TL")
    file.write(veri)
    print(veri)
# Out:
# kalem, 20 TL

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız

def kelimeDegistir():
    eskiKelime = input("Degistirilmesini istediginiz kelimeyi giriniz: ")
    yeniKelime = input("Yeni kelimeyi giriniz: ")

    with open("urunler.txt","r") as file:
        icerik = file.read()
    yeniIcerik = icerik.replace(eskiKelime,yeniKelime)

    with open("urunler.txt","w") as file:
        file.write(yeniIcerik)

kelimeDegistir()

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
# 3.Problemin Çözümünü Buraya Yazınız
class Vehicle:
    def __init__(self,Name,Speed,Mileage):
        self.name = Name
        self.speed = Speed
        self.mileage = Mileage

        
def __str__(self):
        return (f"Name: {self.isim} Speed: {self.hız} Mileage: {self.yakıt_tüketimi}")

class Bus(Vehicle):
    def __init__(self, isim, hız, yakıt_tüketimi):
        super().__init__(isim, hız, yakıt_tüketimi)

# Örnek kullanım:
bus = Bus("School Volvo", 180, 12)
print(bus)
# Out:
# <__main__.Bus object at 0x00000215DCB60F80>
